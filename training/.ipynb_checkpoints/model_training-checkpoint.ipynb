# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS = 3

# %%
tf_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    '../images',
    shuffle = True,
    image_size = (IMAGE_SIZE, IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 4217 files belonging to 4 classes.

# %%
disease_names = tf_dataset.class_names

# %%
plt.figure(figsize = (10,10))
for image_batch, label_batch in tf_dataset.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(disease_names[label_batch[i]])
        plt.axis("off")

# %%
def partition_dataset(ds, train_split = 0.8, validation_split = 0.1, test_split = 0.1, shuffle = True, shuffle_size = 10000):
    ds_size = len(ds)
    if(shuffle):
        ds = ds.shuffle(shuffle_size, seed = 5)

    train_size = int(train_split * ds_size)
    train_ds = ds.take(train_size)

    validation_size = int(validation_split * ds_size)
    validation_ds = ds.skip(train_size).take(validation_size)

    test_size = int(test_split * ds_size)
    test_ds = ds.skip(train_size).skip(validation_size)

    return train_ds, validation_ds, test_ds

# %%
train_ds, val_ds, test_ds = partition_dataset(tf_dataset)

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.Rescaling(1.0/255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomRotation(0.25),
    layers.RandomFlip("horizontal_and_vertical")
])

# %%
inputShape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
numberOfClasses = 4

model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32, (3,3), activation = 'relu', input_shape = inputShape),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, (3,3), activation = 'relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(128, (3,3), activation = 'relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(128, (3,3), activation = 'relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(256, (3,3), activation = 'relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(256, (3,3), activation = 'relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(256, activation = 'relu', kernel_regularizer=l2(0.01)),
    layers.Dropout(0.5),
    layers.BatchNormalization(),
    layers.Dense(numberOfClasses, activation = 'softmax')
])

model.build(input_shape = inputShape)

# %%
model.summary()
# Out:
# Model: "sequential_32"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_30 (Sequential)      │ (32, 256, 256, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_31 (Sequential)      │ (32, 256, 256, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_103 (Conv2D)             │ (32, 254, 254, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_107         │ (32, 254, 254, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_103               │ (32, 127, 127, 32)     │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_104 (Conv2D)             │ (32, 125, 125, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_108         │ (32, 125, 125, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_104               │ (32, 62, 62, 64)       │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_105 (Conv2D)             │ (32, 60, 60, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_109         │ (32, 60, 60, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_105               │ (32, 30, 30, 128)      │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_106 (Conv2D)             │ (32, 28, 28, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_110         │ (32, 28, 28, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_106               │ (32, 14, 14, 128)      │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_107 (Conv2D)             │ (32, 12, 12, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_111         │ (32, 12, 12, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_107               │ (32, 6, 6, 256)        │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_108 (Conv2D)             │ (32, 4, 4, 256)        │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_112         │ (32, 4, 4, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_108               │ (32, 2, 2, 256)        │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_18 (Flatten)            │ (32, 1024)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_36 (Dense)                │ (32, 256)              │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (32, 256)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_113         │ (32, 256)              │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ (32, 4)                │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,393,988 (5.32 MB)
#  Trainable params: 1,391,748 (5.31 MB)
#  Non-trainable params: 2,240 (8.75 KB)

# %%
model.compile(
    optimizer = optimizers.Adam(learning_rate = 0.001),
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
    metrics = ['accuracy']
)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)

# %%
EPOCHS = 50
model.fit(
    train_ds,
    epochs = EPOCHS,
    batch_size = BATCH_SIZE,
    verbose = 1,
    validation_data = val_ds,
    callbacks = [early_stopping, reduce_lr]
)
# Out:
# Epoch 1/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2698s 25s/step - accuracy: 0.4277 - loss: 5.2239 - val_accuracy: 0.3005 - val_loss: 4.4828 - learning_rate: 0.0010
# Epoch 2/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 530s 5s/step - accuracy: 0.5984 - loss: 3.1774 - val_accuracy: 0.3197 - val_loss: 4.4909 - learning_rate: 0.0010
# Epoch 3/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 555s 5s/step - accuracy: 0.6731 - loss: 2.0209 - val_accuracy: 0.3221 - val_loss: 3.2627 - learning_rate: 0.0010
# Epoch 4/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 479s 5s/step - accuracy: 0.7119 - loss: 1.4610 - val_accuracy: 0.4351 - val_loss: 2.3106 - learning_rate: 0.0010
# Epoch 5/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 447s 4s/step - accuracy: 0.7382 - loss: 1.1555 - val_accuracy: 0.6611 - val_loss: 1.1678 - learning_rate: 0.0010
# Epoch 6/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 440s 4s/step - accuracy: 0.7653 - loss: 0.9480 - val_accuracy: 0.7404 - val_loss: 0.9032 - learning_rate: 0.0010
# Epoch 7/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 496s 5s/step - accuracy: 0.7790 - loss: 0.8512 - val_accuracy: 0.8486 - val_loss: 0.6893 - learning_rate: 0.0010
# Epoch 8/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 423s 4s/step - accuracy: 0.7988 - loss: 0.7735 - val_accuracy: 0.8389 - val_loss: 0.6923 - learning_rate: 0.0010
# Epoch 9/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 511s 5s/step - accuracy: 0.8052 - loss: 0.7175 - val_accuracy: 0.8630 - val_loss: 0.5867 - learning_rate: 0.0010
# Epoch 10/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━
0000e-04
# Epoch 35/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 477s 5s/step - accuracy: 0.9030 - loss: 0.3169 - val_accuracy: 0.9279 - val_loss: 0.2726 - learning_rate: 2.0000e-04
# Epoch 36/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 458s 4s/step - accuracy: 0.9154 - loss: 0.3012 - val_accuracy: 0.9303 - val_loss: 0.2685 - learning_rate: 2.0000e-04
# Epoch 37/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 476s 5s/step - accuracy: 0.9003 - loss: 0.3096 - val_accuracy: 0.9087 - val_loss: 0.2813 - learning_rate: 2.0000e-04
# Epoch 38/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 438s 4s/step - accuracy: 0.9043 - loss: 0.3109 - val_accuracy: 0.9279 - val_loss: 0.2388 - learning_rate: 2.0000e-04
# Epoch 39/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 454s 4s/step - accuracy: 0.9118 - loss: 0.2926 - val_accuracy: 0.9111 - val_loss: 0.2942 - learning_rate: 2.0000e-04
# Epoch 40/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 500s 5s/step - accuracy: 0.9183 - loss: 0.2796 - val_accuracy: 0.8894 - val_loss: 0.3564 - learning_rate: 2.0000e-04
# Epoch 41/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 485s 5s/step - accuracy: 0.9059 - loss: 0.3068 - val_accuracy: 0.9087 - val_loss: 0.2905 - learning_rate: 2.0000e-04
# Epoch 42/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 477s 5s/step - accuracy: 0.9120 - loss: 0.2787 - val_accuracy: 0.9231 - val_loss: 0.2544 - learning_rate: 2.0000e-04
# Epoch 43/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 452s 4s/step - accuracy: 0.9187 - loss: 0.2667 - val_accuracy: 0.8774 - val_loss: 0.3498 - learning_rate: 2.0000e-04
# Epoch 44/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 534s 5s/step - accuracy: 0.9131 - loss: 0.2750 - val_accuracy: 0.9351 - val_loss: 0.2313 - learning_rate: 1.0000e-04
# Epoch 45/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 552s 5s/step - accuracy: 0.9210 - loss: 0.2505 - val_accuracy: 0.9351 - val_loss: 0.2293 - learning_rate: 1.0000e-04
# Epoch 46/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 441s 4s/step - accuracy: 0.9164 - loss: 0.2617 - val_accuracy: 0.9303 - val_loss: 0.2431 - learning_rate: 1.0000e-04
# Epoch 47/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 450s 4s/step - accuracy: 0.9335 - loss: 0.2327 - val_accuracy: 0.9375 - val_loss: 0.2073 - learning_rate: 1.0000e-04
# Epoch 48/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 480s 5s/step - accuracy: 0.9283 - loss: 0.2314 - val_accuracy: 0.9447 - val_loss: 0.2090 - learning_rate: 1.0000e-04
# Epoch 49/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 426s 4s/step - accuracy: 0.9326 - loss: 0.2125 - val_accuracy: 0.9495 - val_loss: 0.2041 - learning_rate: 1.0000e-04
# Epoch 50/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 605s 6s/step - accuracy: 0.9264 - loss: 0.2353 - val_accuracy: 0.9351 - val_loss: 0.2062 - learning_rate: 1.0000e-04

# %%
model.evaluate(test_ds)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 180s 775ms/step - accuracy: 0.8971 - loss: 0.2722
# [0.29000166058540344, 0.8928571343421936]

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("FIRST IMAGE : ")
    plt.imshow(first_image)
    print("ACTUAL LABEL : ", disease_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("PREDICTION : ", disease_names[np.argmax(batch_prediction[0])])
# Out:
# FIRST IMAGE :
# ACTUAL LABEL :  normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 666ms/step
# PREDICTION :  normal

# %%
model_name = "eye_classifier_1"
model.export(f"../models/{model_name}")
# Out:
# INFO:tensorflow:Assets written to: ../models/eye_classifier_1\assets
# INFO:tensorflow:Assets written to: ../models/eye_classifier_1\assets
# Saved artifact at '../models/eye_classifier_1'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='keras_tensor_152')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   2423838203472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838203856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838206544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838203280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838204432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838205008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838206736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838207504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838207696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838209040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838209424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838210192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838208656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838209232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838210768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838211728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838211536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838210384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838210000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838211152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838200592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838196752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838205392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838197136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838204624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838199632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838200208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838196560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838199056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838200400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838198288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838196368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838195984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423838197712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423835538256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423835535952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423835538064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423835537488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423835540560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423835537296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423835539792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423835537680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423835541328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423835537872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423835530960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2423835535376: TensorSpec(shape=(), dtype=tf.resource, name=None)
